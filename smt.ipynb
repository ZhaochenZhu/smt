# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinple/smt/blob/main/smt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Dinple/smt
# Out:
# Cloning into 'smt'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 170 (delta 48), reused 85 (delta 29), pack-reused 49
# Receiving objects: 100% (170/170), 553.77 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# !pip install z3-solver
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 52.9 MB 82 kB/s
# ...

# %%
# !cd ./smt
# Out:
# /content

# %%
import os
os.chdir('./smt')
# !pwd
# Out:
# /content/smt

# %%
# !./run_flow.sh
# Out:
# ********** Generating Testcase **********
# genTestCase_cfet.pl [.cdl file] []
# cell: INVx1_ASAP7_75t_R
#
# a   Version Info : 1.0 Initial Version
# a   Generating TestCase pinLayout based on the following files.
# a     Input Circuit :  ./Library/ASAP7_PDKandLIB_v1p5/asap7libs_24/cdl/lvs/asap7_75t_R.cdl
# ...

# %%
# !./clean_run.sh
# Out:
# removed './pinLayouts_cfet_v2.1/INVx1_ASAP7_75t_R.pinLayout'
# removed directory './pinLayouts_cfet_v2.1'
# removed './inputsSMT_cfet/INVx1_ASAP7_75t_R_6T.smt2'
# removed directory './inputsSMT_cfet'
# removed './CFET/PNR_4.5T_Extend/RUN_cfet/INVx1_ASAP7_75t_R_6T.z3_20220727_223004'
# removed './CFET/PNR_4.5T_Extend/RUN_cfet/INVx1_ASAP7_75t_R_6T.z3_20220727_223005'
# removed './CFET/PNR_4.5T_Extend/RUN_cfet/INVx1_ASAP7_75t_R_6T.res_20220727_223005'
# removed './CFET/PNR_4.5T_Extend/RUN_cfet/INVx1_ASAP7_75t_R_6T.res_20220727_223004'
# removed './CFET/PNR_4.5T_Extend/RUN_cfet/INVx1_ASAP7_75t_R_6T.z3'
# removed './CFET/PNR_4.5T_Extend/RUN_cfet/INVx1_ASAP7_75t_R_6T.res'
# removed directory './CFET/PNR_4.5T_Extend/RUN_cfet'
# removed './CFET/PNR_4.5T_Extend/pinLayouts_cfet/INVx1_ASAP7_75t_R.pinLayout'
# removed directory './CFET/PNR_4.5T_Extend/pinLayouts_cfet'
# removed './CFET/PNR_4.5T_Extend/solutionsSMT_cfet/INVx1_ASAP7_75t_R_6T_0_C_0_29_27_0.conv'
# ...
